# %% [markdown]
# ## Read the excel file

# %%
import pandas as pd

# %%
data1=pd.read_excel(r"C:\Users\Bharti\OneDrive\DS & AI\Rawdata.xlsx")

# %%
data1
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %% [markdown]
# ## Read the html file

# %%
data2=pd.read_html(r'C:\Users\Bharti\Downloads\sample_table.html')

# %%
data2
# Out:
# [      Name  Age   Department
#  0  Bharati   23  Development
#  1    Rahul   28      Finance
#  2    Priya   26           HR]

# %% [markdown]
# ## Read the xml file

# %%
data3=pd.read_xml(r"C:\Users\Bharti\PycharmProjects\PythonProject\.idea\workspace.xml")

# %%
data3
# Out:
#                        name    option  list  \
# 0        AutoImportSettings      None   NaN
# 1         ChangeListManager      None   NaN
# 2   FileTemplateManagerImpl  \n         NaN
# 3          ProjectColorInfo      None   NaN
# 4                 ProjectId      None   NaN
# 5          ProjectViewState      None   NaN
# 6       PropertiesComponent      None   NaN
# 7                RunManager      None   NaN
# 8             SharedIndexes      None   NaN
# 9      SpellCheckerSettings      None   NaN
# 10              TaskManager      None   NaN
#
#                                             component  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                        {\n  "associatedIndex": 3\n}
# 4                                                None
# 5                                                None
# ...

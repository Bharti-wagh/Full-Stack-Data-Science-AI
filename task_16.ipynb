# %% [markdown]
# conditional statement

# %% [markdown]
# if statement

# %%
if True: #indentation is always 4 spaces
    print("Data Science")
# Out:
# Data Science

# %%
if True: #indentation is always 4 spaces
    print("Data Science")
    print("I am Beginner now just few years i am definately expert")
# Out:
# Data Science
# I am Beginner now just few years i am definately expert

# %% [markdown]
# if else statement

# %%
if False:
    print("1st print")
else:
    print("2nd print")
# Out:
# 2nd print

# %%
if True:
    print("1st print")
else:
    print("2nd print")
# Out:
# 1st print

# %% [markdown]
# print even numbers only.

# %%
num=10
e=num%2
if e==0:
    print("Even number")
# Out:
# Even number

# %%
num=1
e=num%2
if e==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
num=5
e=num%2
if e==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
num=24
e=num%2
if e!=1:
    print("Even number")
else:
    print("Odd number")
# Out:
# Even number

# %% [markdown]
# nestead if - if inside if.

# %%
num=3
e=num%2
if e==0:
    print("Even number")
    if num>5: #if inside id 
        print("Greater number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
num=4
e=num%2
if e==0:
    print("Even number")
    if num>5: #if inside id 
        print("Greater number")
else:
    print("Odd number")
# Out:
# Even number

# %%
num=8
e=num%2
if e==0:
    print("Even number")
    if num>5: #if inside id 
        print("Greater number")
else:
    print("Odd number")
# Out:
# Even number
# Greater number

# %%
num=4
e=num%2
if e==0:
    print("Even number")
    if num>5: #if inside id 
        print("Greater number")
    else:
        print("Not Greater")
else:
    print("Odd number")
# Out:
# Even number
# Not Greater

# %%
num=3
if num==1:
    print('one')
elif num==2:
    print('Two')
elif num==3:
    print('Three')
elif num==4:
    print('Four')
else:
    print('Not Found')
# Out:
# Three

# %%
num=10
if num==1:
    print('one')
elif num==2:
    print('Two')
elif num==3:
    print('Three')
elif num==4:
    print('Four')
else:
    print('Not Found')
# Out:
# Not Found

# %% [markdown]
# Conditional statement Completed.

# %% [markdown]
# **Dictionary**
#
#
#
#
#
# *   Dictionary is a mutable data type in Python.
# *   A python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed in curly braces {}.
# *   Keys must be unique in a dictionary, duplicate values are allowed.

# %% [markdown]
# ![Screenshot 2025-09-24 140711.png](data:image/png;base64,...)

# %% [markdown]
# **Create Dictionary**

# %%
mydict = dict() # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {} # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {1:'one' , 2:'two' , 3:'three'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = dict({1:'one' , 2:'two' , 3:'three'}) # Create dictionary using dict()
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {'A':'one' , 'B':'two' , 'C':'three'} # dictionary with character keys
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = {1:'one' , 'A':'two' , 3:'three'} # dictionary with mixed keys
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys() # Return Dictionary Keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values() # Return Dictionary Values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items() # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria']} # dictionary with
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria'], 'B':('Bat' , 'cat', 'hat')}
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['asif', 'john', 'Maria'],
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'d': None, 'a': None, 'b': None, 'c': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value = 10
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of
mydict3
# Out:
# {'d': 10, 'a': 10, 'b': 10, 'c': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value = [10,20,30]
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of
mydict3
# Out:
# {'d': [10, 20, 30], 'a': [10, 20, 30], 'b': [10, 20, 30], 'c': [10, 20, 30]}

# %%
value.append(40)
mydict3
# Out:
# {'d': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40]}

# %% [markdown]
# **Accessing Items**

# %%
mydict = {1:'one' , 2:'two' , 3:'three' , 4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1] # Access item using key
# Out:
# 'one'

# %%
mydict.get(1) # Access item using get() method
# Out:
# 'one'

# %%
mydict1 = {'Name':'Bharti' , 'ID': 74123 , 'DOB': 2003 , 'job' :'Analyst'}
mydict1
# Out:
# {'Name': 'Bharti', 'ID': 74123, 'DOB': 2003, 'job': 'Analyst'}

# %%
mydict1['Name'] # Access item using key
# Out:
# 'Bharti'

# %%
mydict1.get('job') # Access item using get() method
# Out:
# 'Analyst'

# %% [markdown]
# **Add, Remove & Change Items**

# %%
mydict1 = {'Name':'Bharti' , 'ID': 12345 , 'DOB': 2003 , 'Address' : 'Chatrapati Sambhajinagar'}
mydict1
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar'}

# %%
mydict1['DOB'] = 1992 # Changing Dictionary Items
mydict1['Address'] = 'Delhi'
mydict1
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1 = {'DOB':1995}
mydict1.update(dict1)
mydict1
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst' # Adding items in the dictionary
mydict1
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 1995,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job') # Removing items in the dictionary using Pop method
mydict1
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem() # A random item is removed
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 1995}

# %%
del[mydict1['ID']] # Removing item using del method
mydict1
# Out:
# {'Name': 'Bharti', 'DOB': 1995}

# %%
mydict1.clear() # Delete all items of the dictionary using clear method
mydict1
# Out:
# {}

# %%
del mydict1 # Delete the dictionary object
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2837195960.py in <cell line: 0>()
#       1 del mydict1 # Delete the dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# **Copy Dictionary**

# %%
mydict = {'Name':'Bharti' , 'ID': 12345 , 'DOB': 2003 , 'Address' : 'Chatrapati Sambhajinagar'}
mydict
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar'}

# %%
mydict1 = mydict # Create a new reference "mydict1"

# %%
id(mydict) , id(mydict1) # The address of both mydict & mydict1 will be the same
# Out:
# (137741125349056, 137741125349056)

# %%
mydict2 = mydict.copy() # Create a copy of the dictionary

# %%
id(mydict2) # The address of mydict2 will be different from mydict
# Out:
# 137741125351424

# %%
mydict['Address'] = 'Mumbai'

# %%
mydict
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 2003, 'Address': 'Mumbai'}

# %%
mydict1 # mydict1 will be also impacted as it is pointing to the same dictionary
# Out:
# {'Name': 'Bharti', 'ID': 12345, 'DOB': 2003, 'Address': 'Mumbai'}

# %%
mydict2 # Copy of list won't be impacted due to the changes made in the original
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar'}

# %% [markdown]
# **Loop through a Dictionary**

# %%
mydict1 = {'Name':'Bharti' , 'ID': 12345 , 'DOB': 2003 , 'Address' : 'Chatrapati Sambhajinagar' ,'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar',
#  'Job': 'Analyst'}

# %%
for i in mydict1:
  print(i , ':' , mydict1[i]) # Key & value pair
# Out:
# Name : Bharti
# ID : 12345
# DOB : 2003
# Address : Chatrapati Sambhajinagar
# Job : Analyst

# %%
for i in mydict1:
  print(mydict1[i]) # Dictionary items
# Out:
# Bharti
# 12345
# 2003
# Chatrapati Sambhajinagar
# Analyst

# %% [markdown]
# **Dictionary Membership**

# %%
mydict1 = {'Name':'Bharti' , 'ID': 12345 , 'DOB': 2003 , 'Address' : 'Chatrapati Sambhajinagar' ,'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar',
#  'Job': 'Analyst'}

# %%
'Name' in mydict1 # Test if a key is in a dictionary or not.
# Out:
# True

# %%
'Bharti' in mydict1 # Membership test can be only done for keys.
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# True

# %% [markdown]
# **All / Any**
#
# The all() method returns:
#
#
# *   True - If all all keys of the dictionary are true
# *   False - If any key of the dictionary is false
#
# The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Bharti' , 'ID': 12345 , 'DOB': 2003 , 'Address' : 'Chatrapati Sambhajinagar' ,'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Bharti',
#  'ID': 12345,
#  'DOB': 2003,
#  'Address': 'Chatrapati Sambhajinagar',
#  'Job': 'Analyst'}

# %%
all(mydict1) # Will Return false as one value is false (Value 0)
# Out:
# True

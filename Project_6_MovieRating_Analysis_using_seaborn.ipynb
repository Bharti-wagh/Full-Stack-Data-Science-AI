# %%
#ADVANCE VISUALIZATION 
import pandas as pd

# %%
movie=pd.read_csv(r'C:\Users\Bharti\OneDrive\DS & AI\28th - Iris, movie analytics Project\28th -Seaborn movie analytics Project\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\movie-rating.csv')

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movie)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.2

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns=['Film','Genre','CriticRating','AudienceRatings','BudgetMillion','Year']

# %%
movie.head(1) #removes noise characters.
# Out:
#                     Film   Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMillion  Year
# 0              8  2009

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.describe() #discriptive statistic
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.Film=movie.Film.astype('category')

# %%
movie.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movie.Genre=movie.Genre.astype('category')

# %%
movie.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movie.Year=movie.Year.astype('category')

# %%
movie.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
from matplotlib import pyplot as pyplot #visualization
import seaborn as sns #Advance visualization
# %matplotlib inline #All the plot should inside the line
import warnings
warnings.filterwarnings('ignore')
# Out:
# UsageError: unrecognized arguments: #All the plot should inside the line

# %% [markdown]
# basically joint plot is a scatter plot & it find the relation b/w audiene & critics
#
# also if you look up you can find the uniform distribution (critics)and normal distriution (audience

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings')

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='kde')

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='hex')

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='reg') #regression lines are visible cleearly using reg

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='resid')

# %%
j=sns.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='scatter')

# %%
#Histogram
#<<<chaart 1
#distribution plot 
m1=sns.distplot(movie.AudienceRatings)
#y axis geneerates by seaborn automatically that is the powerfull of seaborn gallary.
# Out:
# C:\Users\Bharti\AppData\Local\Temp\ipykernel_20160\4266677969.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1=sns.distplot(movie.AudienceRatings)

# %%
m1=sns.distplot(movie.CriticRating)
# Out:
# C:\Users\Bharti\AppData\Local\Temp\ipykernel_20160\589616539.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1=sns.distplot(movie.CriticRating)

# %%
m1=sns.displot(movie.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movie.AudienceRatings,bins=10)
# Out:
# C:\Users\Bharti\AppData\Local\Temp\ipykernel_20160\1107768236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m2=sns.distplot(movie.AudienceRatings,bins=10)

# %%
sns.set_style('darkgrid')
m3=sns.distplot(movie.AudienceRatings,bins=15)
# Out:
# C:\Users\Bharti\AppData\Local\Temp\ipykernel_20160\3021464146.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m3=sns.distplot(movie.AudienceRatings,bins=15)

# %%
sns.set_style('white')
m3=sns.distplot(movie.AudienceRatings,bins=15)
# Out:
# C:\Users\Bharti\AppData\Local\Temp\ipykernel_20160\618731043.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m3=sns.distplot(movie.AudienceRatings,bins=15)

# %%
import matplotlib.pyplot as plt
n1=plt.hist(movie.AudienceRatings,bins=20)

# %%
n1=plt.hist(movie.BudgetMillion)

# %%
vis1=sns.lmplot(data=movie,x='CriticRating',y='AudienceRatings',fit_reg=True)

# %%
vis1=sns.lmplot(data=movie,x='CriticRating',y='AudienceRatings',fit_reg=False)

# %%
vis1=sns.lmplot(data=movie,x='CriticRating',y='AudienceRatings',fit_reg=True,hue='Genre') #hue to color change

# %%
vis1=sns.lmplot(data=movie,x='CriticRating',y='AudienceRatings',fit_reg=False,hue='Genre') #hue to color change

# %%
movie
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
w=sns.boxplot(data=movie,x='Genre',y='CriticRating',hue='Genre')

# %%
z=sns.violinplot(data=movie,x='Genre',y='CriticRating',hue='Genre')

# %%
w1=sns.boxplot(data=movie[movie.Genre=='Drama'],x='Year',y='AudienceRatings',hue='Year')

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre') #kind o subplot

# %%
plt.scatter(movie.CriticRating,movie.AudienceRatings)

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRatings')

# %%
g=sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillion') #histogram are mappe in facetgred
